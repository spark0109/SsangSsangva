# %%
import pandas as pd
# %matplotlib inline
import numpy as np

# %% [markdown]
# ##### 데이터 불러오기

# %%
store_data = pd.read_csv('./서울시_우리마을가게_상권분석서비스(구_상권배후지_소득소비)_utf.csv',encoding = "cp949")

store_data
# Out:
#        기준 년 코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드  상권_코드_명  월_평균_소득_금액  \
# 0         2021         1        A       골목상권  1000193   왕산로43길     2729716
# 1         2021         1        A       골목상권  1000298   정릉로27길     3355209
# 2         2021         1        A       골목상권  1000297   정릉로26길     3338064
# 3         2021         1        A       골목상권  1000296   장위로50길     2416795
# 4         2021         1        A       골목상권  1000295    장월로1길     2956757
# ...        ...       ...      ...        ...      ...      ...         ...
# 31305     2014         4        A       골목상권  1000409    연서로3길     3264390
# 31306     2014         4        A       골목상권  1000906  도산대로23길     3939775
# 31307     2014         4        A       골목상권  1000834      청룡길     3360742
# 31308     2014         4        A       골목상권  1000149   뚝섬로64길     4400547
# 31309     2014         4        A       골목상권  1000444   신촌로37길     3118793
#
# ...

# %%
store_data_mean = store_data.groupby(['상권_코드_명','상권_코드']).mean()
store_data_mean
# Out:
#                        기준 년 코드  기준_분기_코드    월_평균_소득_금액  소득_구간_코드  \
# 상권_코드_명   상권_코드
# 가로공원로58길  1000507  2017.612903  2.548387  2.386094e+06  5.612903
# 가로공원로76가길 1000552  2017.612903  2.548387  2.857454e+06  6.322581
# 가로공원로80길  1000553  2017.612903  2.548387  2.747248e+06  6.064516
# 가마산로61길   1000683  2017.612903  2.548387  3.230116e+06  6.612903
# 가산로3길     1000654  2017.612903  2.548387  2.863283e+06  6.612903
# ...                        ...       ...           ...       ...
# 휘경로23길    1000219  2017.612903  2.548387  3.096393e+06  6.258065
# 휘경로2길     1000220  2017.612903  2.548387  3.405871e+06  7.064516
# 휘경로3길     1000221  2017.612903  2.548387  3.092655e+06  6.258065
# 흑석로13길    1000778  2017.612903  2.548387  3.864120e+06  7.903226
# 흑석로9길     1000779  2017.612903  2.548387  3.698115e+06  7.612903
#
#                          지출_총금액    식료품_지출_총금액  의류_신발_지출_총금액   생활용품_지출_총금액  \
# 상권_코드_명   상권_코드
# 가로공원로58길  1000507  4.719299e+09  1.447646e+09  5.472954e+08  3.396310e+08
# ...

# %%
df_mean_test = store_data.groupby(['상권_코드']).mean()
df_mean_test
# Out:
#              기준 년 코드  기준_분기_코드    월_평균_소득_금액  소득_구간_코드        지출_총금액  \
# 상권_코드
# 1000001  2017.612903  2.548387  3.750819e+06  7.645161  2.926219e+09
# 1000002  2017.612903  2.548387  3.615827e+06  7.612903  5.461795e+09
# 1000003  2017.612903  2.548387  3.156167e+06  6.645161  2.784561e+09
# 1000004  2017.612903  2.548387  3.240188e+06  6.645161  4.232302e+09
# 1000005  2017.612903  2.548387  4.472593e+06  8.129032  2.949243e+09
# ...              ...       ...           ...       ...           ...
# 1001006  2017.612903  2.548387  3.581615e+06  7.612903  9.775271e+09
# 1001007  2017.612903  2.548387  2.990895e+06  6.612903  2.053293e+09
# 1001008  2017.612903  2.548387  3.223246e+06  6.612903  6.779126e+09
# 1001009  2017.612903  2.548387  3.427510e+06  7.000000  9.574848e+09
# 1001010  2017.612903  2.548387  3.312460e+06  6.612903  1.224738e+10
#
#            식료품_지출_총금액  의류_신발_지출_총금액   생활용품_지출_총금액    의료비_지출_총금액     교통_지출_총금액  \
# 상권_코드
# ...

# %% [markdown]
# ### 결측치

# %%
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

matplotlib.matplotlib_fname()

#sns.set(font="NanumGothic-Regular",
 #       rc={"axes.unicode_minus":False})

msno.matrix(df=df_mean_test.iloc[:, :], color=(0.1, 0.6, 0.8))
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51456 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 53076 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 46300 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
#import seaborn as sns
#sns.kdeplot(df_mean_test)

store_data_mean
# Out:
#                        기준 년 코드  기준_분기_코드    월_평균_소득_금액  소득_구간_코드  \
# 상권_코드_명   상권_코드
# 가로공원로58길  1000507  2017.612903  2.548387  2.386094e+06  5.612903
# 가로공원로76가길 1000552  2017.612903  2.548387  2.857454e+06  6.322581
# 가로공원로80길  1000553  2017.612903  2.548387  2.747248e+06  6.064516
# 가마산로61길   1000683  2017.612903  2.548387  3.230116e+06  6.612903
# 가산로3길     1000654  2017.612903  2.548387  2.863283e+06  6.612903
# ...                        ...       ...           ...       ...
# 휘경로23길    1000219  2017.612903  2.548387  3.096393e+06  6.258065
# 휘경로2길     1000220  2017.612903  2.548387  3.405871e+06  7.064516
# 휘경로3길     1000221  2017.612903  2.548387  3.092655e+06  6.258065
# 흑석로13길    1000778  2017.612903  2.548387  3.864120e+06  7.903226
# 흑석로9길     1000779  2017.612903  2.548387  3.698115e+06  7.612903
#
#                          지출_총금액    식료품_지출_총금액  의류_신발_지출_총금액   생활용품_지출_총금액  \
# 상권_코드_명   상권_코드
# 가로공원로58길  1000507  4.719299e+09  1.447646e+09  5.472954e+08  3.396310e+08
# ...

# %%
df = pd.DataFrame( store_data, columns = ["기준 년 코드", "기준_분기_코드", "상권_구분_코드", "상권_구분_코드_명","상권_코드","상권_코드_명","월_평균_소득_금액","소득_구간_코드","지출_총금액"] )

# %%
df
# Out:
#        기준 년 코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드  상권_코드_명  월_평균_소득_금액  \
# 0         2021         1        A       골목상권  1000193   왕산로43길     2729716
# 1         2021         1        A       골목상권  1000298   정릉로27길     3355209
# 2         2021         1        A       골목상권  1000297   정릉로26길     3338064
# 3         2021         1        A       골목상권  1000296   장위로50길     2416795
# 4         2021         1        A       골목상권  1000295    장월로1길     2956757
# ...        ...       ...      ...        ...      ...      ...         ...
# 31305     2014         4        A       골목상권  1000409    연서로3길     3264390
# 31306     2014         4        A       골목상권  1000906  도산대로23길     3939775
# 31307     2014         4        A       골목상권  1000834      청룡길     3360742
# 31308     2014         4        A       골목상권  1000149   뚝섬로64길     4400547
# 31309     2014         4        A       골목상권  1000444   신촌로37길     3118793
#
#        소득_구간_코드       지출_총금액
# 0             6   7501923026
# ...

# %%
starbucks_csv = pd.read_csv("./starbucks.csv")

# %%
starbucks_csv["address_abbr"] = starbucks_csv["address"].str.split()
starbucks_csv
# Out:
#       Unnamed: 0                                            address  \
# 0              0                      광주광역시 광산구 장신로 134, 1~2층 (수완동)
# 1              1                          광주광역시 광산구 임방울대로 487 (수완동)
# 2              2                             광주광역시 광산구 장신로 85 (장덕동)
# 3              3                          광주광역시 광산구 첨단중앙로 104 (월계동)
# 4              4                            광주광역시 광산구 목련로 335 (신가동)
# ...          ...                                                ...
# 1750        1750                             세종특별자치시  도움8로 81 (어진동)
# 1751        1751      세종특별자치시 아름서1길 13-9 (아름동) 103,104,105,202,203호
# 1752        1752                             세종특별자치시 노을3로 101 (한솔동)
# 1753        1753  세종특별자치시 소담3로 8 (소담동) 1동  12호,13호,14호,15호,15a호,16호
# 1754        1754                    세종특별자치시 보듬7로 20 (도담동) 헬스케어센터 1층
#
#             lat        long       name  \
# 0     35.190397  126.824804       광산수완
# 1     35.203175  126.819065     광주수완DT
# ...

# %%
import numpy as np
star_df = np.array(starbucks_csv)
result = []
for data in star_df:
        if "서울특별시" in data.T[1]:
            result.append(data)
result = np.array(result)            
print(result)
# Out:
# [[10 '서울특별시 강남구 언주로 425 (역삼동)' 37.501087 127.043069 '역삼아레나빌딩'
#   list(['서울특별시', '강남구', '언주로', '425', '(역삼동)'])]
#  [11 '서울특별시 강남구 강남대로 538 (논현동)' 37.510178 127.022223 '논현역사거리'
#   list(['서울특별시', '강남구', '강남대로', '538', '(논현동)'])]
#  [12 '서울특별시 강남구 강남대로 584 (논현동)' 37.5139309 127.0206057 '신사역성일빌딩'
#   list(['서울특별시', '강남구', '강남대로', '584', '(논현동)'])]
#  ...
#  [602 '서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층' 37.615368 127.076633 '묵동'
#   list(['서울특별시', '중랑구', '동일로', '952', '(묵동,', '로프트원', '태릉입구역)', '1층'])]
#  [603 '서울특별시 중랑구 양원역로10길 3 (망우동)' 37.6066536267232 127.106359790053 '양원역'
#   list(['서울특별시', '중랑구', '양원역로10길', '3', '(망우동)'])]
#  [604 '서울특별시 중랑구 봉화산로 35 ' 37.60170912407773 127.07841136432036 '중화역'
#   list(['서울특별시', '중랑구', '봉화산로', '35'])]]

# %%
list = []
#list1 = [item for item in starbucks_csv["address_abbr"] if "로" in item ]
#list1 = np.array(starbucks_csv["address_abbr"])
#df = starbucks_csv["address"].filter(lambda i : i[1] )
#df
for item in starbucks_csv["address"]:
    data = item.split()
    if ( data[0] == "서울특별시"):
        for data1 in data:
            if data1.find("길") > 0:
                if data1[-1] != "구":
                    list.append(data1)
                elif data1.find("로") > 0:
                    if data1[-1] != "구":
                        list.append(data1)
#starbucks2 = list
#starbucks_csv["abbr"]
#starbucks1 = starbucks_csv.groupby("abbr")
#starbucks1
df = pd.DataFrame(pd.DataFrame(list).value_counts())
df

#df = pd.DataFrame(list).value_counts()
#df
#df = pd.DataFrame( starbucks_csv["address_abbr_last"].value_counts())
#df
#starbucks_csv["address_abbr_last"] = list
# Out:
#          0
# 0
# (길음동)    2
# 서초대로77길  2
# 마들로3길    2
# 청파로47길   2
# 국제금융로6길  2
# ...     ..
# 마포나루길    1
# 디지털로9길   1
# 디지털로33길  1
# 디지털로26길  1
# 헌릉로569길  1
#
# [96 rows x 1 columns]

# %%
import seaborn as sns

store_data.columns
store_data.drop('기준_분기_코드', axis=1)
store_data.head()
# Out:
#    기준 년 코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명  월_평균_소득_금액  \
# 0     2021         1        A       골목상권  1000193  왕산로43길     2729716
# 1     2021         1        A       골목상권  1000298  정릉로27길     3355209
# 2     2021         1        A       골목상권  1000297  정릉로26길     3338064
# 3     2021         1        A       골목상권  1000296  장위로50길     2416795
# 4     2021         1        A       골목상권  1000295   장월로1길     2956757
#
#    소득_구간_코드       지출_총금액  식료품_지출_총금액  의류_신발_지출_총금액  생활용품_지출_총금액  의료비_지출_총금액  \
# 0         6   7501923026  2151712515     888933146    553108402  1067767035
# 1         7  11842475922  3099929654    1428912815    849935987  1555173516
# 2         7   6179246740  1683952466     733874296    430168476   826003935
# 3         5   5235197988  1501033989     616414129    374450525   756011966
# 4         6   4803914725  1364476852     574723444    344562961   659910597
#
#     교통_지출_총금액  여가_지출_총금액  문화_지출_총금액   교육_지출_총금액  유흥_지출_총금액
# ...

# %%
#store_data = np.array(filter(lambda x: x > 15 and x % 2 == 0 and x % 10 != 0, store_data)) #

# %%
#test1 = pd.DataFrame(store_data)
#test1 = store_data.set_index("상권_코드_명")
#test1

#store_data_mean = pd.merge(left=store_data_mean,right=df, how='inner', left_on="상권_코드_명", right_index=True)
#store_data_mean.info()
import random
rng = np.random.default_rng()
store_data_mean["sbuck_count"] = rng.integers(0, 2,size=(1010, 1))
store_data_mean
# Out:
#                        기준 년 코드  기준_분기_코드    월_평균_소득_금액  소득_구간_코드  \
# 상권_코드_명   상권_코드
# 가로공원로58길  1000507  2017.612903  2.548387  2.386094e+06  5.612903
# 가로공원로76가길 1000552  2017.612903  2.548387  2.857454e+06  6.322581
# 가로공원로80길  1000553  2017.612903  2.548387  2.747248e+06  6.064516
# 가마산로61길   1000683  2017.612903  2.548387  3.230116e+06  6.612903
# 가산로3길     1000654  2017.612903  2.548387  2.863283e+06  6.612903
# ...                        ...       ...           ...       ...
# 휘경로23길    1000219  2017.612903  2.548387  3.096393e+06  6.258065
# 휘경로2길     1000220  2017.612903  2.548387  3.405871e+06  7.064516
# 휘경로3길     1000221  2017.612903  2.548387  3.092655e+06  6.258065
# 흑석로13길    1000778  2017.612903  2.548387  3.864120e+06  7.903226
# 흑석로9길     1000779  2017.612903  2.548387  3.698115e+06  7.612903
#
#                          지출_총금액    식료품_지출_총금액  의류_신발_지출_총금액   생활용품_지출_총금액  \
# 상권_코드_명   상권_코드
# 가로공원로58길  1000507  4.719299e+09  1.447646e+09  5.472954e+08  3.396310e+08
# ...

# %%
#store_data_mean.drop(["0_y"], axis=1)
#store_data_mean.info()
#store_data_mean.rename(columns={'0':'sbuck_count'}, inplace=True)

plt.boxplot(store_data_mean)
plt.show()

# %%
#sns.kdeplot(data=store_data['월_평균_소득_금액'])
#store_data_mean.drop("기준_년_코드", inplace=True)
#from sklearn.datasets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(store_data_mean['월_평균_소득_금액'], store_data_mean['지출_총금액'])

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.boxplot(x_train)
plt.title('정규화 전 - 학습 데이터')
plt.subplot(1, 2, 2)
plt.boxplot(x_test)
plt.title('정규화 전 - 평가 데이터')
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44508 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/conda/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train_scaled = scaler.fit_transform([x_train][:253])
x_test_scaled = scaler.transform([x_test][:253])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_48/2623574471.py in <module>
#       2 scaler = MinMaxScaler()
#       3 x_train_scaled = scaler.fit_transform([x_train][:253])
# ----> 4 x_test_scaled = scaler.transform([x_test][:253])
#
# /opt/conda/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in transform(self, X)
#     494         check_is_fitted(self)
#     495
# --> 496         X = self._validate_data(
#     497             X,
#     498             copy=self.copy,
#
# /opt/conda/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     574
#     575         if not no_val_X and check_params.get("ensure_2d", True):
# --> 576             self._check_n_features(X, reset=reset)
#     577
#     578         return out
#
# ...
